# %%
import pytorch_lightning as pl

from clip_cbm import LitClassifier
from dataset import LitAwA2DM

# %%
# %cat './lightning_logs/AwA2/version_3/hparams.yaml'
# Out:
# accelerator: null
# accumulate_grad_batches: null
# amp_backend: native
# amp_level: null
# auto_lr_find: false
# auto_scale_batch_size: false
# auto_select_gpus: false
# benchmark: null
# bsize: 64
# check_val_every_n_epoch: 1
# data_root_dir: /home/andrewbai/data
# default_root_dir: null
# detect_anomaly: false
# deterministic: null
# devices: null
# enable_checkpointing: true
# enable_model_summary: true
# enable_progress_bar: true
# fast_dev_run: false
# freeze_linear: true
# gpus: null
# gradient_clip_algorithm: null
# gradient_clip_val: null
# img_size: 224
# inference_mode: true
# ipus: null
# latent_dim: 85
# limit_predict_batches: null
# limit_test_batches: null
# limit_train_batches: null
# limit_val_batches: null
# load_linear_path: ./prompts/AwA2_human_prompts.npy
# log_every_n_steps: 50
# logger: true
# lr: 0.001
# max_epochs: null
# max_steps: -1
# max_time: null
# min_epochs: null
# min_steps: null
# move_metrics_to_cpu: false
# ...

# %%
ckpt_path = './lightning_logs/AwA2/version_3/checkpoints/last.ckpt'
model = LitClassifier.load_from_checkpoint(ckpt_path)
# Out:
# Lightning automatically upgraded your loaded checkpoint from v1.8.3.post1 to v1.9.0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file lightning_logs/AwA2/version_3/checkpoints/last.ckpt`
# ...

# %%
model.eval()
# Out:
# LitClassifier(
#   (model): CLIPClassifier(
#     (clip_projector): CLIPVisionModelWithProjection(
#       (vision_model): CLIPVisionTransformer(
#         (embeddings): CLIPVisionEmbeddings(
#           (patch_embedding): Conv2d(3, 768, kernel_size=(32, 32), stride=(32, 32), bias=False)
#           (position_embedding): Embedding(50, 768)
#         )
#         (pre_layrnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (encoder): CLIPEncoder(
#           (layers): ModuleList(
#             (0): CLIPEncoderLayer(
#               (self_attn): CLIPAttention(
#                 (k_proj): Linear(in_features=768, out_features=768, bias=True)
#                 (v_proj): Linear(in_features=768, out_features=768, bias=True)
#                 (q_proj): Linear(in_features=768, out_features=768, bias=True)
#                 (out_proj): Linear(in_features=768, out_features=768, bias=True)
#               )
# ...
